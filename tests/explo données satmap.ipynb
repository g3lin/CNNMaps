# %% [markdown]
# # Install

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
cd "/gdrive/My Drive/Machine Learning - IFT725/Projet SatMap/dataset"
# Out:
# /gdrive/My Drive/Machine Learning - IFT725/Projet SatMap/dataset

# %%
# !pip install tifffile geojsonio geopandas
# Out:
# ...
#      |████████████████████████████████| 931kB 2.7MB/s
# ...
#      |████████████████████████████████| 10.4MB 953kB/s
# ...
#      |████████████████████████████████| 14.7MB 54.3MB/s
# ...

# %%
import pandas as pd
import geopandas as gpd
from PIL import Image
import tifffile as tiff
import matplotlib.pyplot as plt
import geojsonio

# %% [markdown]
# # Explo donnees

# %%
csv = pd.read_csv("grid_sizes.csv")
display(csv)
# Out:
#     Unnamed: 0      Xmax      Ymin
# 0     6120_2_4  0.009180 -0.009040
# 1     6120_2_3  0.009169 -0.009040
# 2     6120_2_2  0.009188 -0.009040
# 3     6120_2_1  0.009188 -0.009040
# 4     6120_2_0  0.009188 -0.009040
# ..         ...       ...       ...
# 445   6130_1_4  0.009169 -0.009040
# 446   6130_1_3  0.009188 -0.009040
# 447   6130_1_2  0.009150 -0.009042
# 448   6130_1_1  0.009004 -0.009045
# 449   6130_1_0  0.009188 -0.009040
#
# [450 rows x 3 columns]

# %%
img3d = tiff.imread('three_band/6040_1_1.tif')

for i in range(len(img3d)):
  plt.figure(i)
  plt.imshow(img3d[i].T)

# %% [markdown]
# **On affiche les images M**
#
# 8 Multispectral: (red, red edge, coastal, blue, green, yellow, near-IR1 and near-IR2) 400 nm - 1040 nm

# %%
img16d = tiff.imread('sixteen_band/6080_0_4_M.tif')
print(img16d.shape)

for i in range(len(img16d)):
  plt.figure(i)
  plt.imshow(img16d[i].T)
# Out:
# (8, 838, 833)

# %% [markdown]
# **On affiche les image A**

# %%
img16d = tiff.imread('sixteen_band/6080_0_4_A.tif')
print(img16d.shape)

for i in range(len(img16d)):
  plt.figure(i)
  plt.imshow(img16d[i].T)
# Out:
# (8, 134, 132)

# %% [markdown]
# # géoJSON

# %%
geojson = gpd.read_file("train_geojson_v3/6010_4_2/002_TR_L4_POOR_DIRT_CART_TRACK.geojson")
display(geojson)
geojsonio.display(geojson.to_json())
# Out:
#                                      ID  ...                                           geometry
# 0  cc9baf48-336e-4419-bc16-a5877bbe7fdb  ...  POLYGON ((0.00265 -0.00249, 0.00280 -0.00231, ...
# 1  69b229d5-2500-49d4-9e85-c3f5d3a11bab  ...  POLYGON ((0.00917 -0.00555, 0.00917 -0.00562, ...
# 2  101c8c29-8a50-42eb-a538-f38115e8564d  ...  POLYGON ((0.00822 -0.00470, 0.00824 -0.00470, ...
# 3  921d5fd6-02ee-4350-8a18-3e5cb7fb7ff8  ...  POLYGON ((0.00752 -0.00434, 0.00771 -0.00415, ...
# 4  5129d368-b80f-4a54-b2ea-145518c22fb7  ...  POLYGON ((0.00827 -0.00467, 0.00825 -0.00467, ...
# 5  006b6b95-ef64-4926-8008-dedcccbe21cd  ...  POLYGON ((0.00347 0.00000, 0.00327 -0.00013, 0...
#
# [6 rows x 6 columns]
# ...
