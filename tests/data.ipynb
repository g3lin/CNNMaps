# %% [markdown]
# # Téléchargement du dataset sur GDrive

# %%
from google.colab import drive
drive.mount("/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
cd "/gdrive/My Drive/Projet SatMap/data"
# Out:
# /gdrive/My Drive/Projet SatMap/dataset

# %%
# !mv "/root/kaggle.json" "/root/.kaggle/kaggle.json"
# !kaggle competitions download -c dstl-satellite-imagery-feature-detection
# Out:
# mv: cannot stat '/root/kaggle.json': No such file or directory
# ...
# three_band.zip: Skipping, found more recently modified local copy (use --force to force download)
# ...
#  35% 5.00M/14.2M [00:00<00:00, 16.8MB/s]
# 100% 14.2M/14.2M [00:00<00:00, 35.7MB/s]
# ...
#   0% 0.00/2.17k [00:00<?, ?B/s]
# 100% 2.17k/2.17k [00:00<00:00, 308kB/s]
# ...
# 100% 7.29G/7.30G [01:53<00:00, 26.0MB/s]
# 100% 7.30G/7.30G [01:55<00:00, 67.6MB/s]
# ...
#   0% 0.00/14.9k [00:00<?, ?B/s]
# 100% 14.9k/14.9k [00:00<00:00, 3.26MB/s]
# ...
#  45% 5.00M/11.1M [00:00<00:00, 26.2MB/s]
# 100% 11.1M/11.1M [00:00<00:00, 43.9MB/s]

# %%
# !unzip grid_sizes.csv.zip 
# !unzip train_geojson_v3.zip  
# !unzip train_wkt_v4.csv.zip  
# !unzip sample_submission.csv.zip 
# !unzip sixteen_band.zip
# Out:
# Archive:  grid_sizes.csv.zip
#   inflating: grid_sizes.csv
# Archive:  train_geojson_v3.zip
#    creating: train_geojson_v3/
#   inflating: train_geojson_v3/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/train_geojson_v3/
#   inflating: __MACOSX/train_geojson_v3/._.DS_Store
#    creating: train_geojson_v3/6010_1_2/
#   inflating: train_geojson_v3/6010_1_2/001_MM_L5_MISC_SMALL_STRUCTURE.geojson
#   inflating: train_geojson_v3/6010_1_2/002_TR_L4_POOR_DIRT_CART_TRACK.geojson
#   inflating: train_geojson_v3/6010_1_2/002_TR_L6_FOOTPATH_TRAIL.geojson
#   inflating: train_geojson_v3/6010_1_2/006_VEG_L5_GROUP_TREES.geojson
#   inflating: train_geojson_v3/6010_1_2/006_VEG_L5_STANDALONE_TREES.geojson
#   inflating: train_geojson_v3/6010_1_2/007_AGR_L2_DEMARCATED_NON_CROP_FIELD.geojson
#   inflating: train_geojson_v3/6010_1_2/007_AGR_L7_FARM_ANIMALS_IN_FIELD.geojson
#   inflating: train_geojson_v3/6010_1_2/Grid_6010.geojson
#    creating: train_geojson_v3/6010_4_2/
# ...

# %%
 
# !kaggle competitions download -c dstl-satellite-imagery-feature-detection --force
# !unzip three_band.zip
# Out:
# ...
# 100% 2.17k/2.17k [00:00<00:00, 8.27kB/s]
#
# ...
#   9% 1.00M/11.1M [00:00<00:04, 2.63MB/s]
# 100% 11.1M/11.1M [00:00<00:00, 22.6MB/s]
# ...
# 100% 7.29G/7.30G [01:55<00:00, 118MB/s]
# 100% 7.30G/7.30G [01:55<00:00, 68.0MB/s]
# ...
# 100% 12.9G/12.9G [04:42<00:00, 55.7MB/s]
# 100% 12.9G/12.9G [04:42<00:00, 49.0MB/s]
# ...
# 100% 14.9k/14.9k [00:00<00:00, 30.1kB/s]
#
# ...
#   7% 1.00M/14.2M [00:01<00:21, 646kB/s]
# 100% 14.2M/14.2M [00:01<00:00, 8.49MB/s]
# Archive:  three_band.zip
#   inflating: three_band/6010_0_0.tif
#   inflating: three_band/6010_0_1.tif
#   inflating: three_band/6010_0_2.tif
#   inflating: three_band/6010_0_3.tif
#   inflating: three_band/6010_0_4.tif
#   inflating: three_band/6010_1_0.tif
#   inflating: three_band/6010_1_1.tif
#   inflating: three_band/6010_1_2.tif
#   inflating: three_band/6010_1_3.tif
#   inflating: three_band/6010_1_4.tif
#   inflating: three_band/6010_2_0.tif
#   inflating: three_band/6010_2_1.tif
#   inflating: three_band/6010_2_2.tif
# ...
